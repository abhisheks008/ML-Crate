# %% [markdown]
# # Search Interests in Google

# %% [markdown]
#  This will help us to Analyze the search interests of the users while they use Google.

# %% [markdown]
# # DataSet
#
#   The dataset of this project is taken from the Kaggle Website. Here is the link of the data set: https://www.kaggle.com/datasets/mustafaadelibrahim/comparing-search-interest-with-google-trends

# %% [markdown]
# # Importing Required Datasets

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Reading the Data and Checking for null Values

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#      Month  Kim Kardashian: (Worldwide) Khloé Kardashian: (Worldwide)  \
# 0  2007-01                            2                            <1
# 1  2007-02                           12                            <1
# 2  2007-03                            9                            <1
# 3  2007-04                            6                            <1
# 4  2007-05                            6                            <1
#
#   Kourtney Kardashian: (Worldwide) Kendall Jenner: (Worldwide)  \
# 0                               <1                          <1
# 1                               <1                          <1
# 2                               <1                          <1
# 3                               <1                          <1
# 4                               <1                          <1
#
#    Kylie Jenner: (Worldwide)  id
# 0                          2   1
# 1                          2   2
# 2                          1   3
# ...

# %%
df.shape
# Out:
# (147, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Month                             147 non-null    object
#  1   Kim Kardashian: (Worldwide)       147 non-null    int64
#  2   Khloé Kardashian: (Worldwide)     147 non-null    object
#  3   Kourtney Kardashian: (Worldwide)  147 non-null    object
#  4   Kendall Jenner: (Worldwide)       147 non-null    object
#  5   Kylie Jenner: (Worldwide)         147 non-null    int64
#  6   id                                147 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.2+ KB

# %%
df.describe()
# Out:
#        Kim Kardashian: (Worldwide)  Kylie Jenner: (Worldwide)          id
# count                   147.000000                 147.000000  147.000000
# mean                     23.367347                   6.870748   66.578231
# std                      11.717614                   7.565488   39.864312
# min                       2.000000                   1.000000    1.000000
# 25%                      15.000000                   1.000000   31.500000
# 50%                      22.000000                   2.000000   66.000000
# 75%                      29.000000                  12.000000  102.500000
# max                     100.000000                  36.000000  134.000000

# %%
df.isna().sum()
# Out:
# Month                               0
# Kim Kardashian: (Worldwide)         0
# Khloé Kardashian: (Worldwide)       0
# Kourtney Kardashian: (Worldwide)    0
# Kendall Jenner: (Worldwide)         0
# Kylie Jenner: (Worldwide)           0
# id                                  0
# dtype: int64

# %% [markdown]
# ## Visualisation of Data

# %%
df2 = df['Kim Kardashian: (Worldwide)']
artist_cou = {'Kim Kardashian: (Worldwide)':list(df2.value_counts().index),
               'Count':list(df2.value_counts().values)}
artist_df = pd.DataFrame(artist_cou)
artist_df.head(12)
# Out:
#     Kim Kardashian: (Worldwide)  Count
# 0                            25     10
# 1                            17      9
# 2                            14      8
# 3                            15      8
# 4                            27      7
# 5                            16      7
# 6                            29      6
# 7                            12      6
# 8                            13      6
# 9                            22      6
# 10                           32      5
# 11                           28      5

# %%
name = artist_df['Kim Kardashian: (Worldwide)'].head(12)
count = artist_df['Count'].head(12)

fig = plt.figure(figsize =(18, 7))
 
plt.pie(count, labels=name,
autopct='%1.1f%%', shadow=True, startangle=140)

fig.legend(bbox_to_anchor=(0.9, 0.8),title = 'Kim Kardashian: (Worldwide)')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
df2 = df['Kylie Jenner: (Worldwide)']
artist_cou = {'Kylie Jenner: (Worldwide)':list(df2.value_counts().index),
               'Count':list(df2.value_counts().values)}
artist_df = pd.DataFrame(artist_cou)
artist_df.head(12)
# Out:
#     Kylie Jenner: (Worldwide)  Count
# 0                           1     49
# 1                           2     27
# 2                           3      9
# 3                          14      6
# 4                          16      6
# 5                          17      6
# 6                          12      5
# 7                           6      4
# 8                           8      4
# 9                          10      4
# 10                          4      3
# 11                         21      3

# %%
name = artist_df['Kylie Jenner: (Worldwide)'].head(12)
count = artist_df['Count'].head(12)

fig = plt.figure(figsize =(18, 7))
 
plt.pie(count, labels=name,
autopct='%1.1f%%', shadow=True, startangle=140)

fig.legend(bbox_to_anchor=(0.9, 0.8),title = 'Kylie Jenner: (Worldwide)')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
df2 = df['Kendall Jenner: (Worldwide)']
artist_cou = {'Kendall Jenner: (Worldwide)':list(df2.value_counts().index),
               'Count':list(df2.value_counts().values)}
artist_df = pd.DataFrame(artist_cou)
artist_df.head(12)
# Out:
#    Kendall Jenner: (Worldwide)  Count
# 0                           <1     40
# 1                            4     21
# 2                            2     18
# 3                            1     16
# 4                            3     12
# 5                            6     11
# 6                            7      9
# 7                            5      8
# 8                            8      7
# 9                            9      3
# 10                          11      2

# %%
name = artist_df['Kendall Jenner: (Worldwide)'].head(12)
count = artist_df['Count'].head(12)

fig = plt.figure(figsize =(18, 7))
 
plt.pie(count, labels=name,
autopct='%1.1f%%', shadow=True, startangle=140)

fig.legend(bbox_to_anchor=(0.9, 0.8),title = 'Kendall Jenner: (Worldwide)')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
df2 = df['Khloé Kardashian: (Worldwide)']
artist_cou = {'Khloé Kardashian: (Worldwide)':list(df2.value_counts().index),
               'Count':list(df2.value_counts().values)}
artist_df = pd.DataFrame(artist_cou)
artist_df.head(12)
# Out:
#    Khloé Kardashian: (Worldwide)  Count
# 0                              3     29
# 1                              5     26
# 2                             <1     24
# 3                              4     23
# 4                              6     14
# 5                              2      9
# 6                              7      9
# 7                              1      7
# 8                              8      2
# 9                             12      1
# 10                            23      1
# 11                             9      1

# %%
name = artist_df['Khloé Kardashian: (Worldwide)'].head(12)
count = artist_df['Count'].head(12)

fig = plt.figure(figsize =(18, 7))
 
plt.pie(count, labels=name,
autopct='%1.1f%%', shadow=True, startangle=140)

fig.legend(bbox_to_anchor=(0.9, 0.8),title = 'Khloé Kardashian: (Worldwide)')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
df2 = df['Kourtney Kardashian: (Worldwide)']
artist_cou = {'Kourtney Kardashian: (Worldwide)':list(df2.value_counts().index),
               'Count':list(df2.value_counts().values)}
artist_df = pd.DataFrame(artist_cou)
artist_df.head(12)
# Out:
#   Kourtney Kardashian: (Worldwide)  Count
# 0                                3     41
# 1                                2     41
# 2                               <1     25
# 3                                4     23
# 4                                1      7
# 5                                5      4
# 6                                8      3
# 7                                6      2
# 8                                7      1

# %%
name = artist_df['Kourtney Kardashian: (Worldwide)'].head(12)
count = artist_df['Count'].head(12)

fig = plt.figure(figsize =(18, 7))
 
plt.pie(count, labels=name,
autopct='%1.1f%%', shadow=True, startangle=140)

fig.legend(bbox_to_anchor=(0.9, 0.8),title = 'Kourtney Kardashian: (Worldwide)')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %% [markdown]
# **So we can say that around the same time frame at first Kendall Jenner was most searched then Kourtney Kardashian
#  then Khole Kardashian then Kim Kardashian was searched then after that Kim Kardashian Search was increased and the others were decreasing but not that much.**

# %%
sns.pairplot(df)

# %% [markdown]
# **This shows that at first, Kim Kardashian was not that much searched and Kylie Jenner was most searched then both of them fell down in searches after reaching their peak searches.**
