# %% [markdown]
# # Importing Basic Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Data Given to us

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Top 5 columns of our dataset

# %%
df.head()
# Out:
#    Ranking         Crypto Name    Price Changes 24H  Changes 7D  Changes 30D   \
# 0        1             BITCOIN  $36,983       -2.97%       1.96%      -20.08%
# 1        2     WRAPPED BITCOIN  $37,019       -2.84%       1.84%      -20.13%
# 2        3          HUOBI BTC   $36,942       -4.24%       1.37%      -20.39%
# 3        4            ETHEREUM   $2,510       -3.64%      -1.28%      -32.04%
# 4        5  LIDO STAKED ETHER    $2,494       -3.23%      -1.84%      -31.98%
#
#   Changes 1Y Market Cap Volume 24H Available Supply
# 0      8.25%  $701.49 B   $13.01 B      18.94 M BTC
# 1      8.26%   $10.04 B  $253.14 M    271.16 K WBTC
# 2      7.82%    $1.47 B   $29.51 M     39.88 K HBTC
# 3     82.54%  $298.87 B   $10.00 B     119.38 M ETH
# 4     95.88%    $4.48 B    $2.07 M     1.79 M STETH

# %% [markdown]
# # Shape of the Dataset given to us

# %%
df.shape
# Out:
# (100, 10)

# %% [markdown]
# # Some Basic Info about our data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ranking           100 non-null    int64
#  1   Crypto Name       100 non-null    object
#  2   Price             100 non-null    object
#  3   Changes 24H       100 non-null    object
#  4   Changes 7D        100 non-null    object
#  5   Changes 30D       100 non-null    object
#  6   Changes 1Y        100 non-null    object
#  7   Market Cap        100 non-null    object
#  8   Volume 24H        100 non-null    object
#  9   Available Supply  99 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 7.9+ KB

# %% [markdown]
# # Checking For null Values

# %%
df.isnull().sum()
# Out:
# Ranking             0
# Crypto Name         0
# Price               0
# Changes 24H         0
# Changes 7D          0
# Changes 30D         0
# Changes 1Y          0
# Market Cap          0
# Volume 24H          0
# Available Supply    1
# dtype: int64

# %% [markdown]
# # Removing Null Values

# %%
df.dropna()
# Out:
#     Ranking         Crypto Name    Price Changes 24H  Changes 7D   \
# 0         1             BITCOIN  $36,983       -2.97%       1.96%
# 1         2     WRAPPED BITCOIN  $37,019       -2.84%       1.84%
# 2         3          HUOBI BTC   $36,942       -4.24%       1.37%
# 3         4            ETHEREUM   $2,510       -3.64%      -1.28%
# 4         5  LIDO STAKED ETHER    $2,494       -3.23%      -1.84%
# ..      ...                 ...      ...          ...         ...
# 95       96               ECOMI   $0.01        -6.53%       4.42%
# 96       97          BITTORRENT   $0.00        $0.00       -1.10%
# 97       98            SAFEMOON   $0.00        -3.19%      -3.72%
# 98       99               ECASH   $0.00        -3.71%      -1.41%
# 99      100           SHIBA INU   $0.00        -6.68%      -8.16%
#
#    Changes 30D  Changes 1Y Market Cap Volume 24H Available Supply
# 0       -20.08%      8.25%  $701.49 B   $13.01 B      18.94 M BTC
# ...

# %% [markdown]
# # Replacing necessary Things for better analysing of dataset

# %%
df['Changes 7D '] = df['Changes 7D '].replace({'%': ''}, regex=True)
df['Changes 7D '] = df['Changes 7D '].replace({'$': ''}, regex=True)

df['Changes 1Y'] = df['Changes 1Y'].replace({'%': ''}, regex=True)
df['Changes 1Y'] = df['Changes 1Y'].replace({'$': ''}, regex=True)

df['Changes 30D '] = df['Changes 30D '].replace({'%': ''}, regex=True)
df['Changes 30D '] = df['Changes 30D '].replace({'$': ''}, regex=True)

# %% [markdown]
# # Data after removing unecessary things

# %%
df.head()
# Out:
#    Ranking         Crypto Name    Price Changes 24H  Changes 7D  Changes 30D   \
# 0        1             BITCOIN  $36,983       -2.97%        1.96       -20.08
# 1        2     WRAPPED BITCOIN  $37,019       -2.84%        1.84       -20.13
# 2        3          HUOBI BTC   $36,942       -4.24%        1.37       -20.39
# 3        4            ETHEREUM   $2,510       -3.64%       -1.28       -32.04
# 4        5  LIDO STAKED ETHER    $2,494       -3.23%       -1.84       -31.98
#
#   Changes 1Y Market Cap Volume 24H Available Supply
# 0       8.25  $701.49 B   $13.01 B      18.94 M BTC
# 1       8.26   $10.04 B  $253.14 M    271.16 K WBTC
# 2       7.82    $1.47 B   $29.51 M     39.88 K HBTC
# 3      82.54  $298.87 B   $10.00 B     119.38 M ETH
# 4      95.88    $4.48 B    $2.07 M     1.79 M STETH

# %% [markdown]
# # Again removing some unnecessary things for better analysing

# %%
df['Changes 24H '] = df['Changes 24H '].replace({'%': ''}, regex=True)
df['Changes 24H '] = df['Changes 24H '].replace({'$': ''}, regex=True)

df['Price'] = df['Price'].replace({'$': ''}, regex=True)

# %% [markdown]
# # Seeing the data after removing the dataset

# %%
df.head()
# Out:
#    Ranking         Crypto Name  Price Changes 24H   Changes 7D  Changes 30D   \
# 0        1             BITCOIN  36983        -2.97         1.96       -20.08
# 1        2     WRAPPED BITCOIN  37019        -2.84         1.84       -20.13
# 2        3          HUOBI BTC   36942        -4.24         1.37       -20.39
# 3        4            ETHEREUM   2510        -3.64        -1.28       -32.04
# 4        5  LIDO STAKED ETHER    2494        -3.23        -1.84       -31.98
#
#   Changes 1Y Market Cap Volume 24H Available Supply
# 0       8.25  $701.49 B   $13.01 B      18.94 M BTC
# 1       8.26   $10.04 B  $253.14 M    271.16 K WBTC
# 2       7.82    $1.47 B   $29.51 M     39.88 K HBTC
# 3      82.54  $298.87 B   $10.00 B     119.38 M ETH
# 4      95.88    $4.48 B    $2.07 M     1.79 M STETH

# %% [markdown]
# # Some info about our dataset after doing the above mentioned things

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ranking           100 non-null    int64
#  1   Crypto Name       100 non-null    object
#  2   Price             100 non-null    int64
#  3   Changes 24H       100 non-null    object
#  4   Changes 7D        100 non-null    float64
#  5   Changes 30D       100 non-null    object
#  6   Changes 1Y        100 non-null    object
#  7   Market Cap        100 non-null    object
#  8   Volume 24H        100 non-null    object
#  9   Available Supply  99 non-null     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.9+ KB

# %% [markdown]
# # Top 5 data of our dataset after data cleansing

# %%
df.head()
# Out:
#    Ranking         Crypto Name  Price Changes 24H  Changes 7D  Changes 30D   \
# 0        1             BITCOIN  36983        -2.97        1.96       -20.08
# 1        2     WRAPPED BITCOIN  37019        -2.84        1.84       -20.13
# 2        3          HUOBI BTC   36942        -4.24        1.37       -20.39
# 3        4            ETHEREUM   2510        -3.64       -1.28       -32.04
# 4        5  LIDO STAKED ETHER    2494        -3.23       -1.84       -31.98
#
#   Changes 1Y Market Cap Volume 24H Available Supply
# 0       8.25  $701.49 B   $13.01 B      18.94 M BTC
# 1       8.26   $10.04 B  $253.14 M    271.16 K WBTC
# 2       7.82    $1.47 B   $29.51 M     39.88 K HBTC
# 3      82.54  $298.87 B   $10.00 B     119.38 M ETH
# 4      95.88    $4.48 B    $2.07 M     1.79 M STETH

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ranking           100 non-null    int64
#  1   Crypto Name       100 non-null    object
#  2   Price             100 non-null    int64
#  3   Changes 24H       100 non-null    object
#  4   Changes 7D        100 non-null    object
#  5   Changes 30D       100 non-null    object
#  6   Changes 1Y        100 non-null    object
#  7   Market Cap        100 non-null    object
#  8   Volume 24H        100 non-null    object
#  9   Available Supply  99 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB

# %% [markdown]
# # Changing the datatype for our analysis of data

# %%
df = df.astype({"Changes 7D ":float })
df = df.astype({"Changes 30D ":float})

# %% [markdown]
# # Last 5 data of our dataset

# %%
df.tail()
# Out:
#     Ranking Crypto Name  Price Changes 24H   Changes 7D   Changes 30D   \
# 95       96       ECOMI      1        -6.53         4.42          9.77
# 96       97  BITTORRENT      0       $0.00         -1.10        -19.83
# 97       98    SAFEMOON      0        -3.19        -3.72        -34.03
# 98       99       ECASH      0        -3.71        -1.41        -32.83
# 99      100   SHIBA INU      0        -6.68        -8.16        -38.56
#
#    Changes 1Y Market Cap Volume 24H Available Supply
# 95    9999.99    $3.99 B    $4.01 M     581.91 B OMI
# 96     481.49    $2.04 B  $283.87 K  932.50 B BTTOLD
# 97       0.00  $933.63 M  $410.28 K     566.50 B SFM
# 98       0.00    $1.40 B   $19.78 M      18.97 T XEC
# 99    9999.99   $11.27 B  $443.94 M    549.15 T SHIB

# %%
df.isna().sum()
# Out:
# Ranking             0
# Crypto Name         0
# Price               0
# Changes 24H         0
# Changes 7D          0
# Changes 30D         0
# Changes 1Y          0
# Market Cap          0
# Volume 24H          0
# Available Supply    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Ranking         Crypto Name  Price Changes 24H   Changes 7D   \
# 0         1             BITCOIN  36983        -2.97         1.96
# 1         2     WRAPPED BITCOIN  37019        -2.84         1.84
# 2         3          HUOBI BTC   36942        -4.24         1.37
# 3         4            ETHEREUM   2510        -3.64        -1.28
# 4         5  LIDO STAKED ETHER    2494        -3.23        -1.84
# ..      ...                 ...    ...          ...          ...
# 95       96               ECOMI      1        -6.53         4.42
# 96       97          BITTORRENT      0       $0.00         -1.10
# 97       98            SAFEMOON      0        -3.19        -3.72
# 98       99               ECASH      0        -3.71        -1.41
# 99      100           SHIBA INU      0        -6.68        -8.16
#
#     Changes 30D  Changes 1Y Market Cap Volume 24H Available Supply
# 0         -20.08       8.25  $701.49 B   $13.01 B      18.94 M BTC
# ...

# %%
df.isnull().sum()
# Out:
# Ranking             0
# Crypto Name         0
# Price               0
# Changes 24H         0
# Changes 7D          0
# Changes 30D         0
# Changes 1Y          0
# Market Cap          0
# Volume 24H          0
# Available Supply    1
# dtype: int64

# %% [markdown]
# # Data Visualisation
#
# ## Crypto vs Prices

# %%
plt.figure(figsize=(20, 10))
df.groupby('Crypto Name')['Price'].mean().sort_values(ascending=True).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Crypto Name'>

# %% [markdown]
# # Crypto vs Crypto Changes in 7D

# %%
plt.figure(figsize=(20, 10))
df.groupby('Crypto Name')['Changes 7D '].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Crypto Name'>

# %% [markdown]
# ## Crypto vs Changes in Rates of Crypto in 30D

# %%
plt.figure(figsize=(20, 10))
df.groupby('Crypto Name')['Changes 30D '].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Crypto Name'>

# %% [markdown]
# ## Pie chart mentioning changes in 7 days

# %%
plt.figure(figsize=(10, 10))
top = df['Changes 7D '].value_counts().sort_values(ascending=False).head()
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Changes 7D '>

# %%
plt.figure(figsize=(10, 10))
top = df['Changes 7D '].value_counts().sort_values(ascending=False).tail()
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Changes 7D '>

# %% [markdown]
# ## Pie Chart for crypto rates changes in 30 Days

# %%
plt.figure(figsize=(10, 10))
top = df['Changes 30D '].value_counts().sort_values(ascending=False).head()
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Changes 30D '>

# %%
plt.figure(figsize=(10, 10))
top = df['Changes 30D '].value_counts().sort_values(ascending=False).tail()
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Changes 30D '>

# %%
sns.pairplot(df)

# %% [markdown]
# ## HeatMap of Dataset

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(), annot = True, linewidths = 1, cmap = 'Pastel1')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Conclusions Drawn after data analysis
#
# * Most of the Crypto currencies prices lies in the range $0 - $1
#
# * In around 7 days most of the rate changes is in negative
#
# * In around 30 days most of them have less negative changes than changes in 7 days
#
# * Some of the crypto currencies have prices more than 30K
#
# * Some of them always changes around negative value
#
# * Many of them have value of zero.

# %% [markdown]
# # Splitting the Data into train and test data

# %%
X = df[['Changes 7D ', 'Changes 30D ']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 10)

# %%
# For containing our data for ML Models
models = []
scores = []

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
lr_score = accuracy_score(y_test, lr_pred)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_score
# Out:
# 0.075

# %%
models.append('Logistic Regression')
scores.append(lr_score)

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
nb_pred = nb.predict(X_test)
nb_score = accuracy_score(y_test, nb_pred)

# %%
nb_score
# Out:
# 0.05

# %%
models.append('Naive Bayes')
scores.append(nb_score)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
svc_pred = svc.predict(X_test)
svc_score = accuracy_score(y_test, svc_pred)

# %%
svc_score
# Out:
# 0.075

# %%
models.append('Support Vector')
scores.append(svc_score)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0
#selecting random state providing the highest accuracy
for x in range(200):
    dtc = DecisionTreeClassifier(random_state=x)
    dtc.fit(X_train,y_train)
    dtc_pred = dtc.predict(X_test)
    current_accuracy = round(accuracy_score(dtc_pred,y_test)*100,2)
    if(current_accuracy > max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

# %%
dtc = DecisionTreeClassifier(random_state = best_x)
dtc.fit(X_train,y_train)
dtc_pred = dtc.predict(X_test)
dtc_score = accuracy_score(y_test, dtc_pred)

# %%
dtc_score
# Out:
# 0.05

# %%
models.append('Decision Tree')
scores.append(dtc_score)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0
#selecting random state providing the highest accuracy
for x in range(200):
    rfc = RandomForestClassifier(random_state = x)
    rfc.fit(X_train,y_train)
    rfc_pred = rfc.predict(X_test)
    current_accuracy = round(accuracy_score(y_test, rfc_pred)*100,2)
    if(current_accuracy > max_accuracy):
        max_accuracy = current_accuracy
        rfc_best_x = x

# %%
rfc = RandomForestClassifier(random_state = rfc_best_x)
rfc.fit(X_train,y_train)
rfc_pred = rfc.predict(X_test)
rfc_score = accuracy_score(y_test, rfc_pred)

# %%
rfc_score
# Out:
# 0.05

# %%
models.append('Random Forest')
scores.append(rfc_score)

# %%
percentage_scores = [score*100 for score in scores]

# %%
plt.figure(figsize=(10,5))
plt.bar(models, percentage_scores)
plt.ylabel('Accuracy')
plt.xlabel('Models')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Conclusions Drawn
#
# * For our dataset Logistic Regression and Support Vector Model is better
