# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/Data.csv')
dataset.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
dataset.drop(columns = ['Unnamed: 0','Photo','Flag','Club Logo','Real Face'],inplace = True)

# %%
dataset.shape

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4190 entries, 0 to 4189
# Data columns (total 84 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        4190 non-null   int64
#  1   Name                      4190 non-null   object
#  2   Age                       4190 non-null   int64
#  3   Nationality               4190 non-null   object
#  4   Overall                   4190 non-null   int64
#  5   Potential                 4190 non-null   int64
#  6   Club                      4149 non-null   object
#  7   Value                     4189 non-null   object
#  8   Wage                      4189 non-null   object
#  9   Special                   4189 non-null   float64
#  10  Preferred Foot            4141 non-null   object
#  11  International Reputation  4141 non-null   float64
#  12  Weak Foot                 4141 non-null   float64
#  13  Skill Moves               4141 non-null   float64
#  14  Work Rate                 4141 non-null   object
#  15  Body Type                 4141 non-null   object
#  16  Position                  4141 non-null   object
#  17  Jersey Number             4141 non-null   float64
#  18  Joined                    3837 non-null   object
#  19  Loaned From               263 non-null    object
#  20  Contract Valid Until      4100 non-null   object
#  21  Height                    4141 non-null   object
#  22  Weight                    4141 non-null   object
#  23  LS                        3714 non-null   object
#  24  ST                        3714 non-null   object
#  25  RS                        3714 non-null   object
#  26  LW                        3714 non-null   object
#  27  LF                        3714 non-null   object
#  28  CF                        3714 non-null   object
#  29  RF                        3714 non-null   object
#  30  RW                        3714 non-null   object
#  31  LAM                       3714 non-null   object
#  32  CAM                       3714 non-null   object
#  33  RAM                       3714 non-null   object
#  34  LM                        3713 non-null   object
#  35  LCM                       3713 non-null   object
#  36  CM                        3713 non-null   object
#  37  RCM                       3713 non-null   object
#  38  RM                        3713 non-null   object
#  39  LWB                       3713 non-null   object
#  40  LDM                       3713 non-null   object
#  41  CDM                       3713 non-null   object
#  42  RDM                       3713 non-null   object
#  43  RWB                       3713 non-null   object
#  44  LB                        3713 non-null   object
#  45  LCB                       3713 non-null   object
#  46  CB                        3713 non-null   object
#  47  RCB                       3713 non-null   object
#  48  RB                        3713 non-null   object
#  49  Crossing                  4140 non-null   float64
#  50  Finishing                 4140 non-null   float64
#  51  HeadingAccuracy           4140 non-null   float64
#  52  ShortPassing              4140 non-null   float64
#  53  Volleys                   4140 non-null   float64
#  54  Dribbling                 4140 non-null   float64
#  55  Curve                     4140 non-null   float64
#  56  FKAccuracy                4140 non-null   float64
#  57  LongPassing               4140 non-null   float64
#  58  BallControl               4140 non-null   float64
#  59  Acceleration              4140 non-null   float64
#  60  SprintSpeed               4140 non-null   float64
#  61  Agility                   4140 non-null   float64
#  62  Reactions                 4140 non-null   float64
#  63  Balance                   4140 non-null   float64
#  64  ShotPower                 4140 non-null   float64
#  65  Jumping                   4140 non-null   float64
#  66  Stamina                   4140 non-null   float64
#  67  Strength                  4140 non-null   float64
#  68  LongShots                 4140 non-null   float64
#  69  Aggression                4140 non-null   float64
#  70  Interceptions             4140 non-null   float64
#  71  Positioning               4140 non-null   float64
#  72  Vision                    4140 non-null   float64
#  73  Penalties                 4140 non-null   float64
#  74  Composure                 4140 non-null   float64
#  75  Marking                   4140 non-null   float64
#  76  StandingTackle            4140 non-null   float64
#  77  SlidingTackle             4140 non-null   float64
#  78  GKDiving                  4140 non-null   float64
#  79  GKHandling                4140 non-null   float64
#  80  GKKicking                 4140 non-null   float64
#  81  GKPositioning             4140 non-null   float64
#  82  GKReflexes                4140 non-null   float64
#  83  Release Clause            3834 non-null   object
# dtypes: float64(39), int64(4), object(41)
# memory usage: 2.7+ MB

# %%
dataset.describe().T
# Out:
#                            count           mean  ...       75%       max
# ID                        4190.0  209859.133174  ...  233074.5  246617.0
# Age                       4190.0      25.562530  ...      29.0      41.0
# Overall                   4190.0      69.986396  ...      77.0      94.0
# Potential                 4190.0      74.322434  ...      80.0      95.0
# Special                   4189.0    1680.539031  ...    1928.0    2346.0
# International Reputation  4141.0       1.381792  ...       2.0       5.0
# Weak Foot                 4141.0       3.028496  ...       3.0       5.0
# Skill Moves               4141.0       2.523545  ...       3.0       5.0
# Jersey Number             4141.0      18.300894  ...      24.0      99.0
# Crossing                  4140.0      53.136473  ...      68.0      93.0
# Finishing                 4140.0      49.053623  ...      65.0      95.0
# HeadingAccuracy           4140.0      54.884783  ...      68.0      94.0
# ShortPassing              4140.0      62.680435  ...      75.0      93.0
# Volleys                   4140.0      46.800000  ...      62.0      90.0
# Dribbling                 4140.0      59.304106  ...      74.0      97.0
# Curve                     4140.0      51.006763  ...      68.0      94.0
# FKAccuracy                4140.0      46.095169  ...      61.0      94.0
# LongPassing               4140.0      56.357729  ...      69.0      93.0
# BallControl               4140.0      62.494203  ...      76.0      96.0
# Acceleration              4140.0      66.412077  ...      76.0      97.0
# SprintSpeed               4140.0      66.500483  ...      76.0      96.0
# Agility                   4140.0      65.499517  ...      76.0      96.0
# Reactions                 4140.0      66.051932  ...      75.0      96.0
# Balance                   4140.0      65.034058  ...      75.0      96.0
# ShotPower                 4140.0      59.043720  ...      74.0      95.0
# Jumping                   4140.0      66.414493  ...      74.0      95.0
# Stamina                   4140.0      65.672464  ...      76.0      96.0
# Strength                  4140.0      66.831884  ...      75.0      95.0
# LongShots                 4140.0      50.921014  ...      68.0      94.0
# Aggression                4140.0      58.592512  ...      73.0      95.0
# Interceptions             4140.0      49.730193  ...      68.0      92.0
# Positioning               4140.0      53.431401  ...      70.0      95.0
# Vision                    4140.0      57.424396  ...      70.0      94.0
# Penalties                 4140.0      51.300725  ...      64.0      92.0
# Composure                 4140.0      63.019565  ...      74.0      96.0
# Marking                   4140.0      50.280193  ...      66.0      94.0
# StandingTackle            4140.0      50.446135  ...      69.0      93.0
# SlidingTackle             4140.0      48.055314  ...      66.0      91.0
# GKDiving                  4140.0      16.659903  ...      14.0      90.0
# GKHandling                4140.0      16.380435  ...      14.0      92.0
# GKKicking                 4140.0      16.149034  ...      14.0      91.0
# GKPositioning             4140.0      16.459903  ...      14.0      90.0
# GKReflexes                4140.0      16.766908  ...      14.0      94.0
#
# [43 rows x 8 columns]

# %%
dataset.isna().sum()
# Out:
# ID                  0
# Name                0
# Age                 0
# Nationality         0
# Overall             0
#                  ...
# GKHandling         50
# GKKicking          50
# GKPositioning      50
# GKReflexes         50
# Release Clause    356
# Length: 84, dtype: int64

# %%
pd.DataFrame(dataset.isna().any()).reset_index()
# Out:
#              index      0
# 0               ID  False
# 1             Name  False
# 2              Age  False
# 3      Nationality  False
# 4          Overall  False
# ..             ...    ...
# 79      GKHandling   True
# 80       GKKicking   True
# 81   GKPositioning   True
# 82      GKReflexes   True
# 83  Release Clause   True
#
# [84 rows x 2 columns]

# %%
plt.subplots(figsize = (15, 5))
sns.countplot(x = dataset['Age'], palette = 'tab10', linewidth = 1, edgecolor = 'black')

# %%
sns.kdeplot(dataset.Overall, shade=True)

# %%
dataset["Preferred Foot"].value_counts().plot(kind="pie",autopct="%.1f%%")

# %%
plt.figure(figsize=(15,5))
position_order = dataset['Position'].value_counts().index
sns.countplot(data=dataset, x='Position',color='blue')

# %%
dataset.head()
# Out:
#        ID               Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0  158023           L. Messi   31  ...          14.0         8.0         €226.5M
# 1   20801  Cristiano Ronaldo   33  ...          14.0        11.0         €127.1M
# 2  190871          Neymar Jr   26  ...          15.0        11.0         €228.1M
# 3  193080             De Gea   27  ...          88.0        94.0         €138.6M
# 4  192985       K. De Bruyne   27  ...          10.0        13.0         €196.4M
#
# [5 rows x 84 columns]

# %%
features = ['International Reputation', 'Overall', 'Potential', 'Reactions', 'Composure', 'Value']
fifa_dataset = dataset[[*features]]
fifa_dataset.head()
# Out:
#    International Reputation  Overall  Potential  Reactions  Composure    Value
# 0                       5.0       94         94       95.0       96.0  €110.5M
# 1                       5.0       94         94       96.0       95.0     €77M
# 2                       5.0       92         93       94.0       94.0  €118.5M
# 3                       4.0       91         93       90.0       68.0     €72M
# 4                       4.0       91         92       91.0       88.0    €102M

# %%
def parseValue(x):
    x = str(x).replace('€', '')
    if('M' in str(x)):
        x = str(x).replace('M', '')
        x = float(x) * 1000000
    elif('K' in str(x)):
        x = str(x).replace('K', '')
        x = float(x) * 1000
    return float(x)

fifa_dataset['Value'] = fifa_dataset['Value'].apply(parseValue)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
fifa_dataset.head()
# Out:
#    International Reputation  Overall  ...  Composure        Value
# 0                       5.0       94  ...       96.0  110500000.0
# 1                       5.0       94  ...       95.0   77000000.0
# 2                       5.0       92  ...       94.0  118500000.0
# 3                       4.0       91  ...       68.0   72000000.0
# 4                       4.0       91  ...       88.0  102000000.0
#
# [5 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(fifa_dataset, test_size=0.2, random_state=42)

# %%
plt.figure(1, figsize=(18, 7))

sns.countplot( x= 'Value', data=train_set)
plt.title('Value distribution of all players')
plt.show()

# %%
train_set = train_set.replace(0, pd.np.nan)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")
imputer.fit(train_set)
# Out:
# SimpleImputer(strategy='median')

# %%
tf = imputer.transform(train_set)
fifa_dataset_tf = pd.DataFrame(tf, columns=fifa_dataset.columns)
fifa_dataset_tf.head()
# Out:
#    International Reputation  Overall  ...  Composure       Value
# 0                       1.0     77.0  ...       75.0  11500000.0
# 1                       1.0     77.0  ...       74.0  12000000.0
# 2                       1.0     62.0  ...       59.0    500000.0
# 3                       1.0     61.0  ...       50.0    200000.0
# 4                       1.0     75.0  ...       63.0   2700000.0
#
# [5 rows x 6 columns]

# %%
plt.figure(figsize = [12, 8])
sns.heatmap(fifa_dataset_tf.corr(), annot = True, fmt = '.3f',
           cmap = 'vlag_r', center = 0)
plt.show()

# %%
fifa_dataset_features = fifa_dataset_tf.drop("Value", axis=1)
fifa_dataset_labels = fifa_dataset_tf["Value"].copy()

# %% [markdown]
# Linear Regression

# %%
lin_reg = LinearRegression()
lin_reg.fit(fifa_dataset_features, fifa_dataset_labels)
fifa_dataset_predictions = lin_reg.predict(fifa_dataset_features)
score = r2_score(fifa_dataset_labels, fifa_dataset_predictions)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 64.99 %

# %% [markdown]
# Decision Trees

# %%
tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(fifa_dataset_features, fifa_dataset_labels)
fifa_dataset_predictions = tree_reg.predict(fifa_dataset_features)
score = r2_score(fifa_dataset_labels, fifa_dataset_predictions)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 99.86 %

# %% [markdown]
# Random Forest

# %%
forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
forest_reg.fit(fifa_dataset_features, fifa_dataset_labels)
fifa_dataset_predictions = forest_reg.predict(fifa_dataset_features)
score = r2_score(fifa_dataset_labels, fifa_dataset_predictions)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 99.04 %
