# %% [markdown]
# # FIDE Chess Ranking Analysis
# The goal of this project is to analyse various chess players around the world.

# %% [markdown]
# # Dataset
# I have Downloaded this dataset from kaggle website. Here is the link: https://www.kaggle.com/datasets/surajjha101/fide-chess-rankings-updated

# %% [markdown]
# # What are we required to do
# We have to analyse various chess players around the world.

# %% [markdown]
# # Importing the Required Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Chess FIDE Rankings.csv')

# %%
df.head()
# Out:
#    rank               name   ELO  title     federation   games  birth_year
# 0      1    Magnus Carlsen   2864    GM         Norway    3125        1990
# 1      2        Liren Ding   2806    GM          China    1630        1992
# 2      3  Alireza Firouzja   2793    GM         France     845        2003
# 3      4    Fabiano Caruana  2783    GM  United States    2622        1992
# 4      5     Levon Aronian   2775    GM  United States    3320        1982

# %%
df.tail()
# Out:
#      rank                       name   ELO  title   federation   games  \
# 195    196            Boris Alterman   2608    GM       Israel     697
# 196    197  Chithambaram VR Aravindh   2608    GM        India     535
# 197    198         Jonas Buhl Bjerre   2608    GM      Denmark     411
# 198    199     Surya Shekhar Ganguly   2608    GM        India    1811
# 199    200               Vadim Milov   2608    GM  Switzerland    1583
#
#      birth_year
# 195        1970
# 196        1999
# 197        2004
# 198        1983
# 199        1972

# %%
df.shape
# Out:
# (200, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         200 non-null    int64
#  1   name         200 non-null    object
#  2   ELO          200 non-null    int64
#  3   title        200 non-null    object
#  4   federation   200 non-null    object
#  5   games        200 non-null    int64
#  6   birth_year   200 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#             rank          ELO         games   birth_year
# count  200.000000   200.000000   200.000000   200.000000
# mean   100.500000  2662.385000  1394.185000  1989.395000
# std     57.879185    47.208793   776.177129     9.057548
# min      1.000000  2608.000000   277.000000  1965.000000
# 25%     50.750000  2623.750000   785.000000  1984.000000
# 50%    100.500000  2650.500000  1211.000000  1990.000000
# 75%    150.250000  2686.000000  1784.000000  1996.000000
# max    200.000000  2864.000000  3913.000000  2006.000000

# %%
df.isna().sum()
# Out:
# rank           0
# name           0
# ELO            0
# title          0
# federation     0
# games          0
# birth_year     0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.columns.tolist()
# Out:
# ['rank ', 'name ', 'ELO ', 'title', 'federation ', 'games', 'birth_year']

# %% [markdown]
# # Visualisation of Data

# %%
df.groupby('name ')['ELO '].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='name '>

# %%
df.groupby('name ')['games'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='name '>

# %%
df.groupby('name ')['games'].mean().nsmallest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='name '>

# %% [markdown]
# # Plotting the Above data in Pie Chart

# %%
plt.figure(figsize=(10, 10))
top = df['title'].value_counts().sort_values(ascending=False).head(13)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='title'>

# %%
plt.pie(df['federation '].value_counts(), labels=df['federation '].value_counts().index,counterclock=False,autopct='%.2f')
plt.title('Participants from each Federations');

# %%
df.rename(columns = {'federation ':'federation'}, inplace = True)

# %%
df.head()
# Out:
#    rank               name   ELO  title      federation  games  birth_year
# 0      1    Magnus Carlsen   2864    GM         Norway    3125        1990
# 1      2        Liren Ding   2806    GM          China    1630        1992
# 2      3  Alireza Firouzja   2793    GM         France     845        2003
# 3      4    Fabiano Caruana  2783    GM  United States    2622        1992
# 4      5     Levon Aronian   2775    GM  United States    3320        1982

# %% [markdown]
# # Visualisation of Data in India

# %%
df_India=df[df.federation=="India "]

# %%
df_India.head()
# Out:
#     rank                     name   ELO  title federation  games  birth_year
# 12     13       Viswanathan Anand   2756    GM     India    3913        1969
# 24     25     Pentala Harikrishna   2720    GM     India    2220        1986
# 27     28  Santosh Gujrathi Vidit   2714    GM     India    1144        1994
# 43     44           Erigaisi Arjun  2689    GM     India     514        2003
# 52     53                Gukesh D   2684    GM     India     569        2006

# %%
df_India.groupby('name ')['ELO '].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='name '>

# %% [markdown]
# # Conclusion
# - Magnus Carlsen has most rating given by FIDE.
# - Viswanathan Anand has played the maximun number of games in FIDE.
# - Aryan Chopra has played the minimun number of games in FIDE.
# - All of the FIDE player has the title of Grandmaster.
# - Maximun numbers of players from Russia.
# - Viswanathan Anand has most rating given by FIDE from India.
