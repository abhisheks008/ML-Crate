# %% [markdown]
# # **World Press Freedom Analysis**

# %% [markdown]
# Importing Libraries and dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # New Section

# %%
df = pd.read_csv('/content/Report_2022.csv')

# %% [markdown]
# Examine dataset

# %%
df['Position 2022 Change'] = df['Position 2021'] - df['Position 2022']
df
# Out:
#          Country ISO Code         Region  Position 2022  Position 2021  \
# 0    Afghanistan      AFG   Asia Pacific            156            122
# 1        Albania      ALB         Europe            103             83
# 2        Algeria      DZA    Arab States            134            146
# 3        Andorra      AND         Europe             53             39
# 4         Angola      AGO         Africa             99            103
# ..           ...      ...            ...            ...            ...
# 175    Venezuela      VEN  South America            159            148
# 176      Vietnam      VNM   Asia Pacific            174            175
# 177        Yemen      YEM   Middle  East            169            169
# 178       Zambia      ZMB         Africa            109            115
# 179     Zimbabwe      ZWE         Africa            137            130
#
#      Global Score  Politic Score  Economic Score  Legislative Score  \
# ...

# %%
df.head()
# Out:
#        Country ISO Code        Region  Position 2022  Position 2021  \
# 0  Afghanistan      AFG  Asia Pacific            156            122
# 1      Albania      ALB        Europe            103             83
# 2      Algeria      DZA   Arab States            134            146
# 3      Andorra      AND        Europe             53             39
# 4       Angola      AGO        Africa             99            103
#
#    Global Score  Politic Score  Economic Score  Legislative Score  \
# 0         38.27          44.65           43.88              42.54
# 1         56.41          50.55           29.39              68.77
# 2         45.53          41.21           32.40              54.17
# 3         68.79          68.12           50.41              69.12
# 4         57.17          52.83           35.03              61.11
#
#    Social Score  Security Score  Journalist Killed  Media Workers Killed  \
# 0         43.33           16.96                  0                     0
# ...

# %%
df.tail()
# Out:
#        Country ISO Code         Region  Position 2022  Position 2021  \
# 175  Venezuela      VEN  South America            159            148
# 176    Vietnam      VNM   Asia Pacific            174            175
# 177      Yemen      YEM   Middle  East            169            169
# 178     Zambia      ZMB         Africa            109            115
# 179   Zimbabwe      ZWE         Africa            137            130
#
#      Global Score  Politic Score  Economic Score  Legislative Score  \
# 175         37.78          33.70           31.73              44.74
# 176         26.11          32.32           18.71              27.49
# 177         29.14          33.03           27.55              38.60
# 178         55.40          52.35           37.76              58.33
# 179         44.94          40.30           32.40              54.17
#
#      Social Score  Security Score  Journalist Killed  Media Workers Killed  \
# ...

# %%
df.shape
# Out:
# (180, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   180 non-null    object
#  1   ISO Code                  179 non-null    object
#  2   Region                    179 non-null    object
#  3   Position 2022             180 non-null    int64
#  4   Position 2021             180 non-null    int64
#  5   Global Score              180 non-null    float64
#  6   Politic Score             180 non-null    float64
#  7   Economic Score            180 non-null    float64
#  8   Legislative Score         180 non-null    float64
#  9   Social Score              180 non-null    float64
#  10  Security Score            180 non-null    float64
#  11  Journalist Killed         180 non-null    int64
#  12  Media Workers Killed      180 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Position 2022  Position 2021  Global Score  Politic Score  \
# count     180.000000     180.000000    180.000000     180.000000
# mean       90.500000      90.500000     58.236944      57.006222
# std        52.105662      52.105662     17.218163      17.196836
# min         1.000000       1.000000     13.920000      22.220000
# 25%        45.750000      45.750000     45.360000      43.790000
# 50%        90.500000      90.500000     59.145000      55.670000
# 75%       135.250000     135.250000     71.120000      70.082500
# max       180.000000     180.000000     92.650000      94.890000
#
#        Economic Score  Legislative Score  Social Score  Security Score  \
# count      180.000000         180.000000    180.000000      180.000000
# mean        45.000611          62.453667     66.353722       60.369556
# std         16.660411          18.155229     18.035181       24.349103
# min          0.000000          15.790000     12.000000        4.630000
# ...

# %%
df.isna().sum()
# Out:
# Country                     0
# ISO Code                    1
# Region                      1
# Position 2022               0
# Position 2021               0
# Global Score                0
# Politic Score               0
# Economic Score              0
# Legislative Score           0
# Social Score                0
# Security Score              0
# Journalist Killed           0
# Media Workers Killed        0
# Journalist Imprisoned       0
# Media Workers Imprisoned    0
# Situation                   0
# Position 2022 Change        0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# Ploting Average Global score by Region

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 10), dpi=72)
sns.barplot(data=df, x='Region', y='Global Score', ax=ax)
ax.set_title('Average Score by Region')
plt.show()

# %%
sns.displot(data=df, x="Position 2022 Change")
plt.title("Number of countries with No, Increased, Decreased ranking")
# Out:
# Text(0.5, 1.0, 'Number of countries with No, Increased, Decreased ranking')

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='Situation', data=df, ax=ax,)
ax.set_title('Count Of Countries by Situation')
# Out:
# Text(0.5, 1.0, 'Count Of Countries by Situation')

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.title('Heatmap')
plt.show()

# %%
df['Situation'].unique()
# Out:
# array(['Very Serious', 'Problematic', 'Difficult', 'Satisfactory', 'Good'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['Region'])
df["Region"] = label

# %%
df.head()
# Out:
#        Country ISO Code  Region  Position 2022  Position 2021  Global Score  \
# 0  Afghanistan      AFG       2            156            122         38.27
# 1      Albania      ALB       3            103             83         56.41
# 2      Algeria      DZA       1            134            146         45.53
# 3      Andorra      AND       3             53             39         68.79
# 4       Angola      AGO       0             99            103         57.17
#
#    Politic Score  Economic Score  Legislative Score  Social Score  \
# 0          44.65           43.88              42.54         43.33
# 1          50.55           29.39              68.77         66.60
# 2          41.21           32.40              54.17         55.88
# 3          68.12           50.41              69.12         68.80
# 4          52.83           35.03              61.11         73.00
#
#    Security Score  Journalist Killed  Media Workers Killed  \
# ...

# %%
from sklearn.model_selection import train_test_split
training_set, test_set = train_test_split(df, test_size = 0.2, random_state=1)

X_train = training_set.iloc[:,2:15].values
Y_train = training_set.iloc[:,15].values
X_test = test_set.iloc[:,2:15].values
Y_test = test_set.iloc[:,15].values\

from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
acc = accuracy_score(Y_test,Y_pred)
print('Naive Bayes Accuracy: ', acc*100,'%')
# Out:
# Naive Bayes Accuracy:  83.33333333333334 %

# %%
from sklearn import svm
clf = svm.LinearSVC(dual=False)
clf.fit(X_train, Y_train)
Ypred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
svm_ac = accuracy_score(Y_test,Ypred)
print('SVM Accuracy: ', svm_ac*100,'%')
# Out:
# SVM Accuracy:  91.66666666666666 %

# %%
from sklearn.tree import DecisionTreeClassifier 
clf = DecisionTreeClassifier() 
clf = clf.fit(X_train,Y_train) 
Yypred = clf.predict(X_test) 

from sklearn.metrics import accuracy_score 
dt_ac = accuracy_score(Y_test,Yypred) 
print('Decision Tree Accuracy: ', dt_ac*100,'%')
# Out:
# Decision Tree Accuracy:  94.44444444444444 %
