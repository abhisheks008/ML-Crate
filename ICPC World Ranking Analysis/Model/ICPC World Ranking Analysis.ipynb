# %% [markdown]
# # ICPC World Ranking Analysis
# Aim of the project to analyze the data for the past 10 years and classify the top coders

# %% [markdown]
# # DataSet
# I have Downloaded this dataset from kaggle website. Here is the link: https://www.kaggle.com/mdjafrilalamshihab/icpc-world-final-ranking-of-last-10-years

# %% [markdown]
# # What are we required to do
# We have to analyse the various coders on basis various fields like medals, Percentage Score, Country etc. and compare each coders.

# %% [markdown]
# # Importing the Required Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('icpc.csv', encoding=('ISO-8859-1'))

# %%
df.head()
# Out:
#    Year    Host  World Final Ranking  \
# 0  2020  Russia                    1
# 1  2020  Russia                    2
# 2  2020  Russia                    3
# 3  2020  Russia                    4
# 4  2020  Russia                    5
#
#                                    University      Country Medal  \
# 0            Nizhny Novgorod State University       Russia   Yes
# 1                   Seoul National University  South Korea   Yes
# 2              St. Petersburg ITMO University       Russia   Yes
# 3  Moscow Institute of Physics and Technology       Russia   Yes
# 4                       University of Wroclaw       Poland   Yes
#
#    Percentage Score  num_of_top_100_last_20_year
# 0             80.00                            8
# 1             73.33                           16
# 2             73.33                           21
# 3             73.33                           11
# 4             73.33                           12

# %%
df.tail()
# Out:
#      Year Host  World Final Ranking  \
# 495  2011  USA                   46
# 496  2011  USA                   47
# 497  2011  USA                   48
# 498  2011  USA                   49
# 499  2011  USA                   50
#
#                                             University    Country Medal  \
# 495                               Princeton University        USA    No
# 496  Universidade de São Paulo - Instituto de Matem...     Brazil    No
# 497  International Institute of Information Technol...      India    No
# 498                       East China Normal University      China    No
# 499            Universidad Nacional de Córdoba - FaMAF  Argentina    No
#
#      Percentage Score  num_of_top_100_last_20_year
# 495             36.36                            6
# 496             36.36                            3
# 497             36.36                            9
# 498             36.36                            4
# 499             36.36                            9

# %%
df.shape
# Out:
# (500, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         500 non-null    int64
#  1   Host                         500 non-null    object
#  2   World Final Ranking          500 non-null    int64
#  3   University                   500 non-null    object
#  4   Country                      500 non-null    object
#  5   Medal                        500 non-null    object
#  6   Percentage Score             500 non-null    float64
#  7   num_of_top_100_last_20_year  500 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#               Year  World Final Ranking  Percentage Score  \
# count   500.000000           500.000000         500.00000
# mean   2015.500000            25.500000          51.82052
# std       2.875158            14.445322          14.05455
# min    2011.000000             1.000000          16.67000
# 25%    2013.000000            13.000000          41.67000
# 50%    2015.500000            25.500000          53.85000
# 75%    2018.000000            38.000000          61.54000
# max    2020.000000            50.000000         100.00000
#
#        num_of_top_100_last_20_year
# count                   500.000000
# mean                     11.088000
# std                       6.458458
# min                       1.000000
# 25%                       5.000000
# 50%                      11.000000
# 75%                      17.000000
# max                      22.000000

# %%
df.isna().sum()
# Out:
# Year                           0
# Host                           0
# World Final Ranking            0
# University                     0
# Country                        0
# Medal                          0
# Percentage Score               0
# num_of_top_100_last_20_year    0
# dtype: int64

# %%
sns.pairplot(df)

# %% [markdown]
# # Visualisation of Data

# %%
plt.figure(figsize=(10, 10))
df.groupby('Country')['Percentage Score'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
plt.figure(figsize=(10, 10))
top = df['Country'].value_counts().sort_values(ascending=False).head(8)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
Medal_win=df[df.Medal=="Yes"]

# %%
Medal_win.head()
# Out:
#    Year    Host  World Final Ranking  \
# 0  2020  Russia                    1
# 1  2020  Russia                    2
# 2  2020  Russia                    3
# 3  2020  Russia                    4
# 4  2020  Russia                    5
#
#                                    University      Country Medal  \
# 0            Nizhny Novgorod State University       Russia   Yes
# 1                   Seoul National University  South Korea   Yes
# 2              St. Petersburg ITMO University       Russia   Yes
# 3  Moscow Institute of Physics and Technology       Russia   Yes
# 4                       University of Wroclaw       Poland   Yes
#
#    Percentage Score  num_of_top_100_last_20_year
# 0             80.00                            8
# 1             73.33                           16
# 2             73.33                           21
# 3             73.33                           11
# 4             73.33                           12

# %%
Medal_win.tail()
# Out:
#      Year Host  World Final Ranking                         University  \
# 457  2011  USA                    8        Donetsk National University
# 458  2011  USA                    9  Jagiellonian University in Krakow
# 459  2011  USA                   10            Moscow State University
# 460  2011  USA                   11              Ural State University
# 461  2011  USA                   12             University of Waterloo
#
#      Country Medal  Percentage Score  num_of_top_100_last_20_year
# 457  Ukraine   Yes             63.64                            1
# 458   Poland   Yes             63.64                           13
# 459   Russia   Yes             63.64                           21
# 460   Russia   Yes             63.64                            8
# 461   Canada   Yes             63.64                           18

# %%
plt.figure(figsize=(10, 10))
top = Medal_win['Country'].value_counts().sort_values(ascending=False).head(8)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
plt.figure(figsize=(10, 10))
top = df['University'].value_counts().sort_values(ascending=False).head(8)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='University'>

# %%
df.University.value_counts().head(100)
# Out:
# Moscow State University                                          10
# University of Warsaw                                             10
# St. Petersburg ITMO University                                   10
# Massachusetts Institute of Technology                            10
# Tsinghua University                                               9
#                                                                  ..
# Kaunas University of Technology                                   1
# Instituto Militar de Engenharia                                   1
# National Technical University "Kharkiv Polytechnic Institute"     1
# Donetsk National University                                       1
# Indian Institute of Technology - Indore                           1
# Name: University, Length: 100, dtype: int64

# %% [markdown]
# # Visualisation of Data in India

# %%
Coders_India=df[df.Country=="India"]

# %%
Coders_India.head()
# Out:
#     Year    Host  World Final Ranking  \
# 29  2020  Russia                   30
# 36  2020  Russia                   37
# 40  2020  Russia                   41
# 44  2020  Russia                   45
# 45  2020  Russia                   46
#
#                                            University Country Medal  \
# 29   Indraprastha Institute of Information Technology   India    No
# 36            Indian Institute of Technology - Bombay   India    No
# 40             Indian Institute of Technology - Delhi   India    No
# 44            Indian Institute of Technology - Kanpur   India    No
# 45  International Institute of Information Technol...   India    No
#
#     Percentage Score  num_of_top_100_last_20_year
# 29             46.67                            1
# 36             40.00                           12
# 40             40.00                            6
# 44             40.00                            7
# 45             33.33                            9

# %%
plt.figure(figsize=(10, 10))
Coders_India.groupby('University')['num_of_top_100_last_20_year'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='University'>

# %%
plt.figure(figsize=(10, 10))
top = Coders_India['University'].value_counts().sort_values(ascending=False).head(10)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='University'>

# %% [markdown]
# # Conclusion
# - Sweden has the maximun avaerge Percentage Score.
# - Maximun Numbers of coders are from Russsia and China.
# - Maximun Number of Medal winners are from Russia.
# - Moscow State University, University of Warsaw, St. Petersburg ITMO University, Massachusetts Institute of Technology have the maximun participations.
# - Indian Institute of Technology-Bombay came to top 100 12 times in last 20 years representing India.
# - International Institute of Information Technology - Hyderabad has maximu n participations from India.
