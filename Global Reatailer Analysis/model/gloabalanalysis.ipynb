# %%
import glob
import pandas as pd
import numpy as np
import seaborn as sns

cm = sns.light_palette("grey", as_cmap=True)

# %% [markdown]
# ## 🧱 Sample dataset
# Here is what a sample of data looks like

# %%
path =r'../input/global-top-250-retailers/' 
allFiles = glob.glob(path + "/cos*.csv") 
allFiles = np.sort(allFiles)

frame = pd.DataFrame()
list_ = []
cols = [ 'name', 
        'country_of_origin', 
        'retail_revenue', 
        'dominant_operational_format', 
        'countries_of_operation', 
        'retail_revenue_cagr'
       ]
i = 1

for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, sep=";", usecols=cols, verbose=False) 
    df["year"] = 2016+i
    list_.append(df)
    del df
    i = i + 1

df = pd.concat(list_)
del list_

#df = df[df["year"].isin([2018, 2019])]
df.sample(10)
# Out:
#                                       name country_of_origin  retail_revenue  \
# 110     Canadian Tire Corporation, Limited            Canada          8635.0
# 160                      Edion Corporation             Japan          6191.0
# 15                       Auchan Holding SA            France         59050.0
# 86       Dairy Farm International Holdings         Hong Kong         11289.0
# 31   LVMH Moët Hennessy-Louis Vuitton S.A.            France         33289.0
# 119                          Colruyt Group           Belgium          7894.0
# 141                        Bic Camera Inc.             Japan          6745.0
# 70                    X5 Retail Group N.V.            Russia         13378.0
# 171                       Coop Danmark A/S           Denmark          5668.0
# 224             HORNBACH Baumarkt AG Group           Germany          4083.0
#
#             dominant_operational_format  countries_of_operation  \
# 110                     Other Specialty                       1
# 160               Electronics Specialty                       1
# 15   Hypermarket/Supercenter/Superstore                      14
# 86                          Supermarket                      11
# 31                      Other Specialty                      70
# 119                         Supermarket                       3
# 141               Electronics Specialty                       1
# 70                       Discount Store                       1
# 171                         Supermarket                       2
# 224                    Home Improvement                       9
#
#      retail_revenue_cagr  year
# 110                0.041  2018
# 160                0.000  2019
# 15                 0.050  2017
# 86                 0.029  2019
# 31                 0.118  2019
# 119                0.050  2017
# 141                0.055  2017
# 70                 0.187  2017
# 171               -0.009  2019
# 224                0.043  2018

# %% [markdown]
# ## 🗺️ From which countries do the top players originate?

# %%
table_country = pd.pivot_table(df, 
                               values='retail_revenue', 
                               index=['country_of_origin'], 
                               columns=['year'], 
                               aggfunc=np.sum
                              )
table_country = table_country.reset_index()
table_country.columns = ["country_of_origin", "revenue_2017", "revenue_2018", "revenue_2019"]
sum_2019 = table_country['revenue_2019'].sum()
table_country = table_country.sort_values(by="revenue_2019", ascending=False).head(10)

table_country
# Out:
#    country_of_origin  revenue_2017  revenue_2018  revenue_2019
# 39                US     1959341.0     2016257.0     2174045.0
# 14           Germany      413241.0      424993.0      469384.0
# 19             Japan      280095.0      316845.0      314434.0
# 13            France      354259.0      348772.0      290637.0
# 38                UK      249289.0      214754.0      229161.0
# 9              China      114259.0      118997.0      138804.0
# 21       Netherlands       93269.0      120780.0      127826.0
# 0          Australia       86045.0       92703.0       96950.0
# 7             Canada       84483.0       85172.0       88582.0
# 31             Spain       72937.0       76395.0       82838.0

# %%
print(f"In 2019 ${np.round(sum_2019.astype(int)/1e6, 1)} Trillion revenue was generated by top 250 retailers; {np.round(100*table_country['revenue_2019'].sum()/sum_2019)}% of these originate from {len(table_country)} countries")
# Out:
# In 2019 $4.6 Trillion revenue was generated by top 250 retailers; 87.0% of these originate from 10 countries

# %% [markdown]
# ## 🇺🇸 Deep dive into firms originating from US

# %%
df_us = df[df["country_of_origin"].isin(["US"]) & (df["year"]==2019)]
cols = ['name', 
        'retail_revenue',
        'dominant_operational_format', 
        'countries_of_operation',
        'retail_revenue_cagr']
df_us = df_us[cols].sort_values(by="retail_revenue", ascending=False).reset_index(drop=True)

df_us.head(10)
# Out:
#                              name  retail_revenue  \
# 0           Wal-Mart Stores, Inc.        500343.0
# 1    Costco Wholesale Corporation        129025.0
# 2                  The Kroger Co.        118982.0
# 3                Amazon.com, Inc.        118573.0
# 4            The Home Depot, Inc.        100904.0
# 5                    Hy-Vee, Inc.        100000.0
# 6  Walgreens Boots Alliance, Inc.         99115.0
# 7          CVS Health Corporation         79398.0
# 8              Target Corporation         71879.0
# 9          Lowe's Companies, Inc.         68619.0
#
#           dominant_operational_format  countries_of_operation  \
# 0  Hypermarket/Supercenter/Superstore                      29
# 1         Cash & Carry/Warehouse Club                      12
# 2                         Supermarket                       1
# 3                           Non-Store                      14
# 4                    Home Improvement                       4
# 5                         Supermarket                       1
# 6                 Drug Store/Pharmacy                      10
# 7                 Drug Store/Pharmacy                       3
# 8           Discount Department Store                       1
# 9                    Home Improvement                       3
#
#    retail_revenue_cagr
# 0                0.013
# 1                0.054
# 2                0.042
# 3                0.180
# 4                0.062
# 5                0.054
# 6                0.067
# 7                0.045
# 8                0.000
# 9                0.063

# %%
agg_dict = {'retail_revenue':['sum', 'median'], 
            'retail_revenue_cagr':['median'],
            'name': lambda x: len(x.unique()),
           }

us_agg = df_us.groupby(["dominant_operational_format"]).agg(agg_dict).reset_index()
us_agg.columns = [' '.join(col).strip() for col in us_agg.columns.values]
us_agg.columns = us_agg.columns.str.replace(' ','_')
us_agg.rename({us_agg.columns[-1]: "n_firms"}, axis=1, inplace=True)

us_agg = us_agg.sort_values(by="retail_revenue_sum", ascending=False).reset_index(drop=True)

us_agg["retail_revenue_sum"] /= 1e3
us_agg["retail_revenue_median"] /= 1e3

rename_dict = {
    "dominant_operational_format": "Retail format",
    "retail_revenue_sum": "Total revenue",
    "retail_revenue_median": "Median revenue",
    "retail_revenue_cagr_median": "Median CAGR",
    "n_firms": "# Firms"
}
format_dict = {
    'Total revenue':'${0:,.0f}', 
    'Median revenue':'${0:,.0f}',
    'Median CAGR': '{:.1%}'          
}

#us_agg
(
    us_agg.rename(rename_dict, axis=1)
    .style
    .bar(subset=['Median CAGR'], align='mid', color=['#d65f5f', '#5fba7d'])
    .background_gradient(subset=['Total revenue', '# Firms'], cmap=cm)
    .format(format_dict).hide_index()
    .bar(color='#5fba7d', vmin=0, subset=['Median revenue'], align='zero')
    .set_caption('2019 United States top retailers ($Billion)')
)
# Out:
# <style  type="text/css" >
#     #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row0_col1 {
#             background-color:  #808080;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 52.7%, transparent 52.7%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row0_col4 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row1_col1 {
#             background-color:  #969696;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.7%, transparent 51.7%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 59.4%, transparent 59.4%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row1_col4 {
#             background-color:  #979797;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row2_col1 {
#             background-color:  #c9c9c9;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 65.3%, transparent 65.3%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 59.4%, transparent 59.4%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row2_col4 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row3_col1 {
#             background-color:  #cacaca;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 57.6%, transparent 57.6%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 69.2%, transparent 69.2%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row3_col4 {
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row4_col1 {
#             background-color:  #d3d3d3;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.5%, transparent 52.5%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 64.4%, transparent 64.4%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row4_col4 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row5_col1 {
#             background-color:  #d4d4d4;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.1%, transparent 51.1%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 63.3%, transparent 63.3%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row5_col4 {
#             background-color:  #808080;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row6_col1 {
#             background-color:  #d5d5d5;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.5%, transparent 51.5%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row6_col4 {
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row7_col1 {
#             background-color:  #dbdbdb;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.4%, transparent 52.4%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.1%, #d65f5f 33.1%, #d65f5f 34.2%, transparent 34.2%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row7_col4 {
#             background-color:  #c5c5c5;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row8_col1 {
#             background-color:  #dcdcdc;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.2%, transparent 52.2%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 66.1%, transparent 66.1%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row8_col4 {
#             background-color:  #cacaca;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row9_col1 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 57.0%, transparent 57.0%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, #5fba7d 34.2%, #5fba7d 53.5%, transparent 53.5%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row9_col4 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row10_col1 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 63.8%, transparent 63.8%);
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row10_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_fd76d6ce_8d2b_11ea_9eb8_bf650086fae7row10_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_fd

# %% [markdown]
# ## 🛒 2019 Global top retailers

# %%
agg_dict = {'retail_revenue':['sum', 'median'], 
            'retail_revenue_cagr':['median'],
            'name': lambda x: len(x.unique()),
           }

us_agg = df[df["year"]==2019].groupby(["dominant_operational_format"]).agg(agg_dict).reset_index()
us_agg.columns = [' '.join(col).strip() for col in us_agg.columns.values]
us_agg.columns = us_agg.columns.str.replace(' ','_')
us_agg.rename({us_agg.columns[-1]: "n_firms"}, axis=1, inplace=True)

us_agg = us_agg.sort_values(by="retail_revenue_sum", ascending=False).reset_index(drop=True)

us_agg["retail_revenue_sum"] /= 1e3
us_agg["retail_revenue_median"] /= 1e3

rename_dict = {
    "dominant_operational_format": "Retail format",
    "retail_revenue_sum": "Total revenue",
    "retail_revenue_median": "Median revenue",
    "retail_revenue_cagr_median": "Median CAGR",
    "n_firms": "# Firms"
}
format_dict = {
    'Total revenue':'${0:,.0f}', 
    'Median revenue':'${0:,.0f}',
    'Median CAGR': '{:.1%}'          
}

#us_agg
(
    us_agg.rename(rename_dict, axis=1)
    .style
    .bar(subset=['Median CAGR'], align='mid', color=['#d65f5f', '#5fba7d'])
    .background_gradient(subset=['Total revenue', '# Firms'], cmap=cm)
    .format(format_dict).hide_index()
    .bar(color='#5fba7d', vmin=0, subset=['Median revenue'], align='zero')
    .set_caption('2019 Global top retailers ($Billion)')
)
# Out:
# <style  type="text/css" >
#     #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row0_col1 {
#             background-color:  #808080;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 79.3%, transparent 79.3%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.8%, transparent 11.8%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row0_col4 {
#             background-color:  #808080;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row1_col1 {
#             background-color:  #868686;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.0%, transparent 80.0%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.8%, transparent 11.8%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row1_col4 {
#             background-color:  #c2c2c2;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row2_col1 {
#             background-color:  #cacaca;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.7%, transparent 80.7%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 23.9%, transparent 23.9%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row2_col4 {
#             background-color:  #d2d2d2;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row3_col1 {
#             background-color:  #d3d3d3;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 69.2%, transparent 69.2%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.0%, transparent 22.0%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row3_col4 {
#             background-color:  #acacac;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row4_col1 {
#             background-color:  #d6d6d6;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 68.5%, transparent 68.5%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.1%, transparent 20.1%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row4_col4 {
#             background-color:  #d9d9d9;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row5_col1 {
#             background-color:  #d9d9d9;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 81.6%, transparent 81.6%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.2%, transparent 18.2%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row5_col4 {
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row6_col1 {
#             background-color:  #dbdbdb;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 79.5%, transparent 79.5%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.3%, transparent 21.3%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row6_col4 {
#             background-color:  #cfcfcf;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row7_col1 {
#             background-color:  #dcdcdc;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.1%, transparent 86.1%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.3%, transparent 57.3%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row7_col4 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row8_col1 {
#             background-color:  #dddddd;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 75.5%, transparent 75.5%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.5%, transparent 4.5%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row8_col4 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row9_col1 {
#             background-color:  #dedede;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 85.0%, transparent 85.0%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.2%, transparent 9.2%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row9_col4 {
#             background-color:  #dbdbdb;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row10_col1 {
#             background-color:  #dfdfdf;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.1%, transparent 92.1%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.5%, transparent 10.5%);
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row10_col4 {
#             background-color:  #ebebeb;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row11_col1 {
#             background-color:  #e2e2e2;
#             color:  #000000;
#         }    #T_fd823028_8d2b_11ea_9eb8_bf650086fae7row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(9
