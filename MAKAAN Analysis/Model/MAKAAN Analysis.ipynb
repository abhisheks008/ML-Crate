# %% [markdown]
# # MAKAAN Analysis
# Aim of the project to analyse the Prices of Housing Property.

# %% [markdown]
# # DataSet
# I have Downloaded this dataset from kaggle website. Here is the link: https://www.kaggle.com/datasets/manishmathias/residential-property-price-indian-cities-dataset

# %% [markdown]
# # What are we required to do
# We have to analyse the Prices of Housing Property.

# %% [markdown]
# # Importing the Required Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Makaan_Properties_Buy.csv',encoding=('ISO-8859-1'))

# %%
df.head()
# Out:
#                Property_Name  Property_id Property_type     Property_status  \
# 0               Arkiton Luxe     15446514     Apartment  Under Construction
# 1  Keshav Akshar Ocean Pearl     15367414     Apartment  Under Construction
# 2            Vishwa Opulence     14683118     Apartment       Ready to move
# 3              Satyam Sarjan      5476295     Apartment       Ready to move
# 4           Navkar Sunflower     15477040     Apartment  Under Construction
#
#   Price_per_unit_area   Posted_On  \
# 0               4,285   1 day ago
# 1               7,000  2 days ago
# 2               5,752  2 days ago
# 3               2,486  5 days ago
# 4               5,324  8 days ago
#
#                                          Project_URL   builder_id  \
# 0  https://www.makaan.com/ahmedabad/arkiton-life-...  100563465.0
# 1  https://www.makaan.com/ahmedabad/keshav-naraya...  100009433.0
# 2  https://www.makaan.com/ahmedabad/vishwa-develo...  100207731.0
# ...

# %%
df.tail()
# Out:
#                     Property_Name  Property_id Property_type  \
# 332091  Rajlaxmi RaajLaxmi Towers     10324765     Apartment
# 332092  Rajlaxmi RaajLaxmi Towers     15076701     Apartment
# 332093  Rajlaxmi RaajLaxmi Towers     10324762     Apartment
# 332094  Rajlaxmi RaajLaxmi Towers     15076700     Apartment
# 332095  Rajlaxmi RaajLaxmi Towers     14683740     Apartment
#
#            Property_status Price_per_unit_area     Posted_On  \
# 332091  Under Construction               9,826  4 months ago
# 332092  Under Construction               8,568  4 months ago
# 332093  Under Construction               9,861  4 months ago
# 332094  Under Construction               8,813  4 months ago
# 332095  Under Construction               9,859  4 months ago
#
#                                               Project_URL  builder_id  \
# 332091  https://www.makaan.com/mumbai/rajlaxmi-develop...    561277.0
# 332092  https://www.makaan.com/mumbai/rajlaxmi-develop...    561277.0
# ...

# %%
df.shape
# Out:
# (332096, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332096 entries, 0 to 332095
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Property_Name             217826 non-null  object
#  1   Property_id               332096 non-null  int64
#  2   Property_type             332096 non-null  object
#  3   Property_status           271654 non-null  object
#  4   Price_per_unit_area       332096 non-null  object
#  5   Posted_On                 332096 non-null  object
#  6   Project_URL               332096 non-null  object
#  7   builder_id                149978 non-null  float64
#  8   Builder_name              149978 non-null  object
#  9   Property_building_status  332096 non-null  object
#  10  City_id                   332096 non-null  int64
#  11  City_name                 332096 non-null  object
#  12  No_of_BHK                 332096 non-null  object
# ...

# %%
df.describe()
# Out:
#         Property_id    builder_id        City_id    Locality_ID  \
# count  3.320960e+05  1.499780e+05  332096.000000  332096.000000
# mean   1.319382e+07  1.108900e+07      12.137861   63082.944775
# std    2.533792e+06  3.100384e+07       7.270491   26246.913783
# min    5.000114e+06  1.000020e+05       1.000000   50001.000000
# 25%    1.244466e+07  1.006780e+05       5.000000   50378.000000
# 50%    1.419741e+07  1.034750e+05      12.000000   51893.000000
# 75%    1.509555e+07  6.547740e+05      18.000000   60223.000000
# max    1.558147e+07  1.007295e+08      23.000000  173237.000000
#
#            Longitude       Latitude   Sub_urban_ID  listing_domain_score
# count  332096.000000  332096.000000  332096.000000         332096.000000
# mean       77.626544      19.761817   10140.731770              4.005565
# std         4.163027       5.311124     197.784494              0.124058
# min        23.526030       8.403612   10003.000000              4.000000
# ...

# %%
df.isna().sum()
# Out:
# Property_Name               114270
# Property_id                      0
# Property_type                    0
# Property_status              60442
# Price_per_unit_area              0
# Posted_On                        0
# Project_URL                      0
# builder_id                  182118
# Builder_name                182118
# Property_building_status         0
# City_id                          0
# City_name                        0
# No_of_BHK                        0
# Locality_ID                      0
# Locality_Name                    2
# Longitude                        0
# Latitude                         0
# Price                            0
# Size                             0
# Sub_urban_ID                     0
# Sub_urban_name                   0
# description                      1
# is_furnished                     0
# listing_domain_score             0
# is_plot                          0
# is_RERA_registered               0
# is_Apartment                     0
# ...

# %% [markdown]
# # Changing of DataType for Better Visualization of Data.

# %%
df['Price_per_unit_area'] = df['Price_per_unit_area'].str.replace(',', '').astype(np.int64)
df['Price_per_unit_area'] = pd.to_numeric(df['Price_per_unit_area'])

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(np.int64)
df['Price'] = pd.to_numeric(df['Price'])

# %%
df['Size'] = df['Size'].str.replace(' sq ft', '')
df['Size'] = df['Size'].str.replace(',', '').astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332096 entries, 0 to 332095
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Property_Name             217826 non-null  object
#  1   Property_id               332096 non-null  int64
#  2   Property_type             332096 non-null  object
#  3   Property_status           271654 non-null  object
#  4   Price_per_unit_area       332096 non-null  int64
#  5   Posted_On                 332096 non-null  object
#  6   Project_URL               332096 non-null  object
#  7   builder_id                149978 non-null  float64
#  8   Builder_name              149978 non-null  object
#  9   Property_building_status  332096 non-null  object
#  10  City_id                   332096 non-null  int64
#  11  City_name                 332096 non-null  object
#  12  No_of_BHK                 332096 non-null  object
# ...

# %%
df.head()
# Out:
#                Property_Name  Property_id Property_type     Property_status  \
# 0               Arkiton Luxe     15446514     Apartment  Under Construction
# 1  Keshav Akshar Ocean Pearl     15367414     Apartment  Under Construction
# 2            Vishwa Opulence     14683118     Apartment       Ready to move
# 3              Satyam Sarjan      5476295     Apartment       Ready to move
# 4           Navkar Sunflower     15477040     Apartment  Under Construction
#
#    Price_per_unit_area   Posted_On  \
# 0                 4285   1 day ago
# 1                 7000  2 days ago
# 2                 5752  2 days ago
# 3                 2486  5 days ago
# 4                 5324  8 days ago
#
#                                          Project_URL   builder_id  \
# 0  https://www.makaan.com/ahmedabad/arkiton-life-...  100563465.0
# 1  https://www.makaan.com/ahmedabad/keshav-naraya...  100009433.0
# 2  https://www.makaan.com/ahmedabad/vishwa-develo...  100207731.0
# ...

# %% [markdown]
# # Visualisation of Data

# %%
df.groupby('Property_Name')['Price_per_unit_area'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Property_Name'>

# %%
df.groupby('Property_Name')['Price'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Property_Name'>

# %%
df.groupby('Property_Name')['Size'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Property_Name'>

# %%
df.groupby('Builder_name')['Size'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Builder_name'>

# %%
df.groupby('Builder_name')['Price'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Builder_name'>

# %%
df.groupby('Builder_name')['Price_per_unit_area'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Builder_name'>

# %%
df.groupby('City_name')['Price_per_unit_area'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='City_name'>

# %%
df.groupby('City_name')['Price'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='City_name'>

# %%
df.groupby('City_name')['Size'].mean().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='City_name'>

# %% [markdown]
# # Plotting the Above data in Pie Chart

# %%
plt.figure(figsize=(10, 10))
top = df['is_furnished'].value_counts().sort_values(ascending=False)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_furnished'>

# %%
plt.figure(figsize=(10, 10))
top = df['is_RERA_registered'].value_counts().sort_values(ascending=False).head(13)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_RERA_registered'>

# %%
plt.figure(figsize=(10, 10))
top = df['is_Apartment'].value_counts().sort_values(ascending=False).head(13)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_Apartment'>

# %%
plt.figure(figsize=(10, 10))
top = df['is_commercial_Listing'].value_counts().sort_values(ascending=False).head(13)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_commercial_Listing'>

# %%
plt.figure(figsize=(10, 10))
top = df['is_PentaHouse'].value_counts().sort_values(ascending=False)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_PentaHouse'>

# %%
plt.figure(figsize=(10, 10))
top = df['is_studio'].value_counts().sort_values(ascending=False)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='is_studio'>

# %%
plt.figure(figsize=(10, 10))
top = df['Listing_Category'].value_counts().sort_values(ascending=False)
top.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Listing_Category'>

# %% [markdown]
# # Conclusion
# - Navgrow Home 1 has highest price per unit area.
# - Off S P ring road R 3 zone 9k sy has highest price.
# - R3 plot covers maximun area.
# - Resolute Property Solutions owns maximun area.
# - Golf Links earns highest price.
# - Golf Links earns highest price per unit area.
# - Price are highest in Delhi.
# - Price per unit area are highest in Delhi.
# - Most of the housing are located in Ahmedabad.
# - Most of the housing are unfurnished.
# - Most of the housing are not RERA registered.
# - Most of the housing are apartments.
# - Most of the housing are not commercial listing.
# - Most of the housing are not pentahouse.
# - Most of the housing are not studio.
# - Most of the housing are for sale.
